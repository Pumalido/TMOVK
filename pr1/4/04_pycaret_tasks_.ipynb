# %% [markdown]
# # PyCaret - открытая low-code библиотека машинного обучения на Python

# %% [markdown]
# ![PyCaret.png](data:image/png;base64,...)

# %%
# !pip install numpy==1.20.3 scikit-learn==0.23.2
# !pip install -pre pycaret
# Out:
# ...
#   Using cached numpy-1.20.3.zip (7.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
# ...

# %% [markdown]
# # 2. Install numpy lib to avoid errors in using PyCaret
# pip install numpy==1.20.3 scikit-learn==0.23.2
#
# pip install --pre pycaret

# %% [markdown]
# 3. Импортируем библиотеки для регрессионного анализа из PyCaret

# %%
# 3. Import PyCaret regression libs
from pycaret.regression import *

# %% [markdown]
# 4. Импортируем библиотеки PyCaret для работы с наборами данных и регрессией
# from pycaret.datasets import get_data  # Импортируем функцию get_data из модуля datasets библиотеки PyCaret, которая позволяет загружать различные наборы данных.
#
# Получаем список всех доступных наборов данных
# all_datasets = get_data('index')  # Вызываем функцию get_data с аргументом 'index', чтобы получить индекс всех доступных наборов данных в PyCaret и сохранить его в переменной all_datasets.

# %%
# 4. Import PyCaret regression libs and review PyCaret's datasets
from pycaret.datasets import get_data
all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# 5. Загружаем набор данных 'Insurance'
# При загрузке вам нужно нажать 'Enter' в поле ниже
# data = get_data('insurance')  # Используем функцию get_data для загрузки набора данных 'insurance' и сохраняем его в переменной data.
#
# Настраиваем среду для регрессионного анализа
# reg = setup(
#     data=data,  # Передаем загруженный набор данных в функцию setup.
#     target='charges',  # Указываем целевую переменную, которую мы хотим предсказать (в данном случае 'charges' - расходы на страховку).
#     train_size=0.8,  # Устанавливаем размер обучающей выборки на 80% от общего объема данных.
#     session_id=10,  # Устанавливаем идентификатор сессии для воспроизводимости результатов.
#     normalize=True  # Включаем нормализацию данных, чтобы привести их к одному масштабу, что может улучшить качество модели.
# )

# %%
# 5. Load dataset 'Insurance'
# While loading you should press 'Enter' in field below
data=get_data('insurance')
reg = setup(
    data=data,
    target='charges',
    train_size=0.8,
    session_id=10,
    normalize=True
)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_f8378_row9_col1, #T_f8378_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8378" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8378_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8378_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8378_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8378_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# 7. Просмотр нормализованных признаков
# get_config('X')  # Используем функцию get_config для получения нормализованных признаков из текущей конфигурации PyCaret.

# %%
# 7. Review normalized features
get_config('X')
# Out:
#       age     sex        bmi  children smoker     region
# 559    19    male  35.529999         0     no  northwest
# 273    50    male  27.455000         1     no  northeast
# 471    18  female  30.115000         0     no  northeast
# 22     18    male  34.099998         0     no  southeast
# 939    53    male  29.480000         0     no  southeast
# ...   ...     ...        ...       ...    ...        ...
# 271    50    male  34.200001         2    yes  southwest
# 695    26  female  40.185001         0     no  northwest
# 1039   19    male  27.264999         2     no  northwest
# 323    57    male  40.945000         0     no  northeast
# 835    42    male  35.970001         2     no  southeast
#
# [1338 rows x 6 columns]

# %% [markdown]
# Функция get_config('X') возвращает набор признаков после предобработки.
#
# Как можно увидеть, чсленные значения признаков были нормализованы с помощью Z-оценки, а категориальные призанки были закодированы с помощью метода быстрого кодирования ("one-hot encoding"). Очень важно проверить результаты нормализации, в некоторых случаях она может быть выполнена некорректно, что повлияет на возможность обучить классификатр и получить верные занчения.
#
# Нормализация Z-оценки относится к процессу нормализации каждого значения в наборе данных, так что среднее значение всех значений равно 0, а стандартное отклонение равно 1.
#
# Мы используем следующую формулу для нормализации z-оценки для каждого значения в наборе данных:
#
# Новое значение = (x – μ) / σ
#
# где:
#
# х : Исходное значение
#
# μ : Среднее значение данных
#
# σ : стандартное отклонение данных

# %% [markdown]
# 8. Подготовка к магии ;) Оценка всех моделей одной строкой кода
# Сравниваем модели
# best = compare_models()  # Используем функцию compare_models для автоматического сравнения всех доступных моделей регрессии.

# %%
# 8. Prepare to magic;) Evaluate all models by 1 line of code
# compare models
best = compare_models()
# Out:
# <style type="text/css">
# #T_4ae9e th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Визуализация модели
# plot_model(best)  # Используем функцию plot_model для создания графиков, которые помогают визуализировать производительность лучшей модели.

# %%
plot_model(best)

# %% [markdown]
# Визуализация важности признаков
# plot_model(best, plot='feature')  # Используем функцию plot_model для отображения важности признаков лучшей модели.

# %%
# Feature Importance
plot_model(best, plot = 'feature')

# %% [markdown]
# Визуализация кривой обучения
# plot_model(best, plot='learning')  # Используем функцию plot_model для отображения кривой обучения лучшей модели.

# %%
plot_model(best, plot = 'learning')

# %% [markdown]
# Выполните следующие задания:
# * Импортируйте набор данных 'diabetes'
# * Выполните импорт всех библиотек из модуля classification библиотеки pycaret
# * Настройте эксперимент, цель - значения столбца 'Class variable'
# * Выполните поиск наилучшей модели
# * Определите наиболее значимые признаки
# * Выполните графическое построение наилучшей модели

# %% [markdown]
# Импортируйте набор данных 'diabetes'

# %%
from pycaret.datasets import get_data

# Загрузка набора данных 'diabetes'
data = get_data('diabetes')
print(data.head())  # Просмотр первых строк данных
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# Выполните импорт всех библиотек из модуля classification библиотеки pycaret

# %%
from pycaret.classification import *

# %% [markdown]
# Настройте эксперимент, цель - значения столбца 'Class variable'

# %%
# Настройка эксперимента
clf_setup = setup(
    data=data,
    target='Class variable',  # Целевая переменная
    session_id=42,            # Для воспроизводимости
    normalize=True,           # Нормализация данных
    train_size=0.8            # 80% данных для обучения
)
# Out:
# <style type="text/css">
# #T_7fb76_row8_col1, #T_7fb76_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7fb76" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fb76_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7fb76_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fb76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fb76_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7fb76_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_7fb76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7fb76_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7fb76_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Выполните поиск наилучшей модели

# %%
# Сравнение моделей
best_model = compare_models()
print(best_model)
# Out:
# <style type="text/css">
# #T_f1e68 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Определите наиболее значимые признаки

# %%
# Построение графика важности признаков
plot_model(best_model, plot='feature')

# %% [markdown]
# Выполните графическое построение наилучшей модели

# %%
# Построение графика оценки модели
plot_model(best_model)

# Построение кривой обучения
plot_model(best_model, plot='learning')
